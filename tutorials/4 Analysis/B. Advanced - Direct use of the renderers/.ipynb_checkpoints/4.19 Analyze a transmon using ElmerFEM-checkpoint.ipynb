# %% [markdown]
# # Analyse a Transmon Qubit using ElmerFEM
# This notebook demonstrates the new open-source rendering and simulation capabilities of Qiskit Metal using `Gmsh` and `ElmerFEM` for tuning the performance parameters of a transmon qubit. instructions to download and install this branch of Qiskit Metal with Gmsh and ElmerFEM, can he found [here](https://github.com/Qiskit/qiskit-metal/blob/elmer_renderer/tutorials/4%20Analysis/B.%20Advanced%20-%20Direct%20use%20of%20the%20renderers/Gmsh-Elmer-install-instructions.md) The tutorial has the following steps:
#
# ## Contents
# ### 1. Creating a Transmon Qubit in Qiskit Metal
# ### 2. Rendering and meshing your design in the `QGmshRenderer`
# - Rendering the design wireframe
# - Applying a basic mesh
# - Customizing the mesh
#     - Setting initial mesh size parameters
#     - Using the Intelli-mesh feature in `QGmshRenderer`
# - Saving your mesh to a file
#
# ### 3. Rendering your design in `QElmerRenderer` (uses `QGmshRenderer`)
# - Render design and generate mesh
# - Export the mesh
# - Run the capacitance simulation
#     - Add solution setup
#     - Run the solver
#     - Export capacitance matrix
#
# ### 4. Perform LOM 2.0 Analysis
# - Import the capacitance matrix
# - Define cells and subsystems
# - Define the composite system
# - Compute the results:
#     - Qubit Frequency ($f_Q$)
#     - Anharmonicity ($\alpha$)
#     - Readout $\chi$
#     - Coupling $g$

# %% [markdown]
# > 💡 **Using this tutorial without the Qt GUI**
# >
# > This tutorial uses the desktop `MetalGUI`. To follow along on Colab, Binder, JupyterHub, or any environment where Qt isn't available, **replace any `gui.rebuild()` / `gui.screenshot()` call with `qm.view(design)`** — it renders the design to a matplotlib `Figure` you can display inline or save with `fig.savefig(...)`.
# >
# > See [1.4 Headless quick view](../1-Overview/1.4-Headless-quick-view-%28no-Qt-GUI%29.ipynb) for a complete runnable walkthrough and [`docs/headless-usage.rst`](../../../docs/headless-usage.rst) for the full reference.

# %% [markdown]
# # Necessary Imports

# %%
# %load_ext autoreload
# %autoreload 2

# Import basic things of Qiskit Metal
from qiskit_metal import MetalGUI, designs
from qiskit_metal.qlibrary.qubits.transmon_pocket_6 import TransmonPocket6

# Import the Gmsh renderer
from qiskit_metal.renderers.renderer_gmsh.gmsh_renderer import QGmshRenderer

# Import the Elmer renderer
from qiskit_metal.renderers.renderer_elmer.elmer_renderer import QElmerRenderer
from qiskit_metal.renderers.renderer_elmer.elmer_renderer import (
    load_capacitance_matrix_from_file,
)
# Out:
# 03:06AM 11s WARNING [_maybe_warn_import_rename]: [FutureWarning] A future major release of quantum-metal (target v0.8 / v1.0) will rename the Python import path from `qiskit_metal` to `quantum_metal` to match the PyPI package name. Plan to update your imports ahead of that release. See ROADMAP.md and the README rebrand notice. Suppress this warning with QISKIT_METAL_SUPPRESS_RENAME_WARNING=1.

# %%
# %metal_heading 1. Create a Transmon Qubit in Qiskit Metal
# Out:
#     <h1 style="
#         background: #12c2e9;  /* fallback for old browsers */
#         background: -webkit-linear-gradient(to right, #d4418e 0%, #0652c5 74%);  /* Chrome 10-25, Safari 5.1-6 */
#         background: linear-gradient(315deg, #d4418e 0%, #0652c5 74%); /* W3C, IE 10+/ Edge, Firefox 16+, Chrome 26+, Opera 12+, Safari 7+ */
#         margin-top: 50px;
#         border-style: outset;
#         padding-top:100px;
#         padding-bottom:50px;
#         padding-left:25px;
#         color: white;
#     "> 1. Create a Transmon Qubit in Qiskit Metal <h1>

# %%
# Instantiate a design object
design = designs.MultiPlanar({}, True)

# Invoke the Qiskit Metal GUI
gui = MetalGUI(design)

# %%
# Define a dictionary for connection pad options for the transmon
conn_pads = dict(
    connection_pads=dict(
        readout=dict(loc_W=0, loc_H=-1),
        coupler1=dict(loc_W=-1, loc_H=1),
        coupler2=dict(loc_W=1, loc_H=1),
    )
)

# Create a TransmonPocket6 object
q1 = TransmonPocket6(design, "Q1", options=dict(**conn_pads))

# Rebuild and autoscale the GUI
gui.rebuild()
gui.autoscale()

# %%
gui.screenshot()

# %%
# %metal_heading 2. Rendering and meshing your design in the `QGmshRenderer`
# Out:
#     <h1 style="
#         background: #12c2e9;  /* fallback for old browsers */
#         background: -webkit-linear-gradient(to right, #d4418e 0%, #0652c5 74%);  /* Chrome 10-25, Safari 5.1-6 */
#         background: linear-gradient(315deg, #d4418e 0%, #0652c5 74%); /* W3C, IE 10+/ Edge, Firefox 16+, Chrome 26+, Opera 12+, Safari 7+ */
#         margin-top: 50px;
#         border-style: outset;
#         padding-top:100px;
#         padding-bottom:50px;
#         padding-left:25px;
#         color: white;
#     "> 2. Rendering and meshing your design in the `QGmshRenderer` <h1>

# %% [markdown]
# ## Rendering the design wireframe

# %%
# Instantiate the Gmsh renderer
gmsh_renderer = QGmshRenderer(design)

# Render the design
# Tip: `mesh_geoms = False` will not mesh the design,
# but only draw the wire-frame of the geomtries
gmsh_renderer.render_design(
    open_pins=[("Q1", "coupler1"), ("Q1", "coupler2"), ("Q1", "readout")],
    mesh_geoms=False,
)
# Out:
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views

# %%
# Launch Gmsh GUI to see the rendererd design
gmsh_renderer.launch_gui()
# Out:
# -------------------------------------------------------
# Version       : 4.15.0
# License       : GNU General Public License
# Build OS      : MacOSARM-sdk
# Build date    : 20251026
# Build host    : gmsh.info
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blas[petsc] Blossom Cgns DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack Lapack[petsc] MathEx[contrib] Med Mesh Metis[contrib] Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom PETSc Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] TouchBar Untangle Voro++[contrib] WinslowUntangler Zlib tinyobjloader
# FLTK version  : 1.4.0
# PETSc version : 3.17.4 (real arithmtic)
# OCC version   : 7.8.1
# MED version   : 4.1.0
# Packaged by   : geuzaine
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:957ac30d-cd89-42b5-8a95-3bff0c12139d.png)

# %% [markdown]
# ## Applying a basic mesh

# %%
# Add a basic mesh to the design and luanch the GUI to view
gmsh_renderer.add_mesh(dim=3, intelli_mesh=False)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [  0%] Meshing curve 265 (Line)
# Info    : [  0%] Meshing curve 293 (Line)
# Info    : [  0%] Meshing curve 209 (Line)
# Info    : [  0%] Meshing curve 376 (Line)
# Info    : [  0%] Meshing curve 321 (Line)
# Info    : [  0%] Meshing curve 349 (Line)
# Info    : [  0%] Meshing curve 294 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 210 (Line)
# Info    : [ 10%] Meshing curve 377 (Line)
# Info    : [ 10%] Meshing curve 350 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 10%] Meshing curve 295 (Line)
# Info    : [ 10%] Meshing curve 211 (Line)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 296 (Line)
# Info    : [ 10%] Meshing curve 351 (Line)
# Info    : [ 10%] Meshing curve 212 (Line)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 297 (Line)
# Info    : [ 10%] Meshing curve 213 (Line)
# Info    : [ 10%] Meshing curve 6 (Line)
# Info    : [ 10%] Meshing curve 352 (Line)
# Info    : [ 10%] Meshing curve 7 (Line)
# Info    : [ 10%] Meshing curve 214 (Line)
# Info    : [ 10%] Meshing curve 298 (Line)
# Info    : [ 10%] Meshing curve 299 (Line)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 300 (Line)
# Info    : [ 10%] Meshing curve 301 (Line)
# Info    : [ 10%] Meshing curve 215 (Line)
# Info    : [ 20%] Meshing curve 9 (Line)
# Info    : [  0%] Meshing curve 237 (Line)
# Info    : [ 20%] Meshing curve 378 (Line)
# Info    : [ 20%] Meshing curve 302 (Line)
# Info    : [ 20%] Meshing curve 238 (Line)
# Info    : [ 20%] Meshing curve 10 (Line)
# Info    : [ 20%] Meshing curve 322 (Line)
# Info    : [ 20%] Meshing curve 379 (Line)
# Info    : [ 20%] Meshing curve 303 (Line)
# Info    : [ 20%] Meshing curve 216 (Line)
# Info    : [ 20%] Meshing curve 304 (Line)
# Info    : [ 20%] Meshing curve 380 (Line)
# Info    : [ 20%] Meshing curve 11 (Line)
# Info    : [ 20%] Meshing curve 381 (Line)
# Info    : [ 20%] Meshing curve 382 (Line)
# Info    : [ 20%] Meshing curve 305 (Line)
# Info    : [ 20%] Meshing curve 239 (Line)
# Info    : [ 20%] Meshing curve 383 (Line)
# Info    : [ 20%] Meshing curve 12 (Line)
# Info    : [ 20%] Meshing curve 306 (Line)
# Info    : [ 20%] Meshing curve 217 (Line)
# Info    : [ 20%] Meshing curve 323 (Line)
# Info    : [ 20%] Meshing curve 307 (Line)
# Info    : [ 30%] Meshing curve 193 (Line)
# Info    : [ 30%] Meshing curve 218 (Line)
# Info    : [ 30%] Meshing curve 308 (Line)
# Info    : [ 30%] Meshing curve 194 (Line)
# Info    : [ 30%] Meshing curve 195 (Line)
# Info    : [ 30%] Meshing curve 384 (Line)
# Info    : [ 30%] Meshing curve 309 (Line)
# Info    : [ 30%] Meshing curve 196 (Line)
# Info    : [ 30%] Meshing curve 240 (Line)
# Info    : [ 30%] Meshing curve 310 (Line)
# Info    : [ 30%] Meshing curve 219 (Line)
# Info    : [ 30%] Meshing curve 197 (Line)
# Info    : [ 30%] Meshing curve 311 (Line)
# Info    : [ 30%] Meshing curve 198 (Line)
# Info    : [ 30%] Meshing curve 220 (Line)
# Info    : [ 30%] Meshing curve 385 (Line)
# Info    : [ 20%] Meshing curve 353 (Line)
# Info    : [ 30%] Meshing curve 199 (Line)
# Info    : [ 30%] Meshing curve 266 (Line)
# Info    : [ 30%] Meshing curve 241 (Line)
# Info    : [ 30%] Meshing curve 386 (Line)
# Info    : [ 40%] Meshing curve 200 (Line)
# Info    : [ 40%] Meshing curve 324 (Line)
# Info    : [ 40%] Meshing curve 221 (Line)
# Info    : [ 40%] Meshing curve 312 (Line)
# Info    : [ 40%] Meshing curve 201 (Line)
# Info    : [ 40%] Meshing curve 387 (Line)
# Info    : [ 40%] Meshing curve 202 (Line)
# Info    : [ 40%] Meshing curve 222 (Line)
# Info    : [ 40%] Meshing curve 203 (Line)
# Info    : [ 40%] Meshing curve 313 (Line)
# Info    : [ 40%] Meshing curve 267 (Line)
# Info    : [ 40%] Meshing curve 223 (Line)
# Info    : [ 40%] Meshing curve 204 (Line)
# Info    : [ 40%] Meshing curve 354 (Line)
# Info    : [ 40%] Meshing curve 314 (Line)
# Info    : [ 40%] Meshing curve 242 (Line)
# Info    : [ 40%] Meshing curve 205 (Line)
# Info    : [ 40%] Meshing curve 268 (Line)
# Info    : [ 40%] Meshing curve 224 (Line)
# Info    : [ 40%] Meshing curve 325 (Line)
# Info    : [ 50%] Meshing curve 206 (Line)
# Info    : [ 50%] Meshing curve 243 (Line)
# Info    : [ 50%] Meshing curve 388 (Line)
# Info    : [ 50%] Meshing curve 315 (Line)
# Info    : [ 50%] Meshing curve 225 (Line)
# Info    : [ 50%] Meshing curve 207 (Line)
# Info    : [ 50%] Meshing curve 316 (Line)
# Info    : [ 50%] Meshing curve 355 (Line)
# Info    : [ 50%] Meshing curve 208 (Line)
# Info    : [ 50%] Meshing curve 226 (Line)
# Info    : [ 50%] Meshing curve 244 (Line)
# Info    : [ 50%] Meshing curve 235 (Line)
# Info    : [ 50%] Meshing curve 326 (Line)
# Info    : [ 50%] Meshing curve 317 (Line)
# Info    : [ 50%] Meshing curve 227 (Line)
# Info    : [ 50%] Meshing curve 269 (Line)
# Info    : [ 50%] Meshing curve 389 (Line)
# Info    : [ 50%] Meshing curve 228 (Line)
# Info    : [ 50%] Meshing curve 245 (Line)
# Info    : [ 50%] Meshing curve 390 (Line)
# Info    : [ 50%] Meshing curve 356 (Line)
# Info    : [ 50%] Meshing curve 229 (Line)
# Info    : [ 60%] Meshing curve 236 (Line)
# Info    : [ 60%] Meshing curve 246 (Line)
# Info    : [ 60%] Meshing curve 230 (Line)
# Info    : [ 60%] Meshing curve 247 (Line)
# Info    : [ 60%] Meshing curve 270 (Line)
# Info    : [ 60%] Meshing curve 318 (Line)
# Info    : [ 60%] Meshing curve 327 (Line)
# Info    : [ 60%] Meshing curve 231 (Line)
# Info    : [ 60%] Meshing curve 391 (Line)
# Info    : [ 60%] Meshing curve 234 (Line)
# Info    : [ 60%] Meshing curve 357 (Line)
# Info    : [ 60%] Meshing curve 232 (Line)
# Info    : [ 60%] Meshing curve 392 (Line)
# Info    : [ 60%] Meshing curve 271 (Line)
# Info    : [ 60%] Meshing curve 248 (Line)
# Info    : [ 60%] Meshing curve 233 (Line)
# Info    : [ 60%] Meshing curve 328 (Line)
# Info    : [ 60%] Meshing curve 319 (Line)
# Info    : [ 60%] Meshing curve 261 (Line)
# Info    : [ 60%] Meshing curve 358 (Line)
# Info    : [ 60%] Meshing curve 258 (Line)
# Info    : [ 60%] Meshing curve 262 (Line)
# Info    : [ 60%] Meshing curve 359 (Line)
# Info    : [ 60%] Meshing curve 393 (Line)
# Info    : [ 60%] Meshing curve 249 (Line)
# Info    : [ 60%] Meshing curve 272 (Line)
# Info    : [ 60%] Meshing curve 360 (Line)
# Info    : [ 60%] Meshing curve 329 (Line)
# Info    : [ 60%] Meshing curve 394 (Line)
# Info    : [ 60%] Meshing curve 259 (Line)
# Info    : [ 70%] Meshing curve 263 (Line)
# Info    : [ 70%] Meshing curve 250 (Line)
# Info    : [ 70%] Meshing curve 330 (Line)
# Info    : [ 70%] Meshing curve 395 (Line)
# Info    : [ 70%] Meshing curve 320 (Line)
# Info    : [ 70%] Meshing curve 264 (Line)
# Info    : [ 70%] Meshing curve 361 (Line)
# Info    : [ 70%] Meshing curve 260 (Line)
# Info    : [ 70%] Meshing curve 251 (Line)
# Info    : [ 70%] Meshing curve 257 (Line)
# Info    : [ 70%] Meshing curve 396 (Line)
# Info    : [ 70%] Meshing curve 256 (Line)
# Info    : [ 70%] Meshing curve 362 (Line)
# Info    : [ 70%] Meshing curve 255 (Line)
# Info    : [ 70%] Meshing curve 331 (Line)
# Info    : [ 70%] Meshing curve 252 (Line)
# Info    : [ 70%] Meshing curve 397 (Line)
# Info    : [ 70%] Meshing curve 253 (Line)
# Info    : [ 70%] Meshing curve 345 (Line)
# Info    : [ 70%] Meshing curve 398 (Line)
# Info    : [ 70%] Meshing curve 363 (Line)
# Info    : [ 70%] Meshing curve 399 (Line)
# Info    : [ 70%] Meshing curve 332 (Line)
# Info    : [ 80%] Meshing curve 254 (Line)
# Info    : [ 80%] Meshing curve 288 (Line)
# Info    : [ 80%] Meshing curve 400 (Line)
# Info    : [ 80%] Meshing curve 364 (Line)
# Info    : [ 80%] Meshing curve 285 (Line)
# Info    : [ 80%] Meshing curve 401 (Line)
# Info    : [ 80%] Meshing curve 286 (Line)
# Info    : [ 80%] Meshing curve 289 (Line)
# Info    : [ 80%] Meshing curve 287 (Line)
# Info    : [ 80%] Meshing curve 333 (Line)
# Info    : [ 80%] Meshing curve 365 (Line)
# Info    : [ 80%] Meshing curve 282 (Line)
# Info    : [ 80%] Meshing curve 280 (Line)
# Info    : [ 80%] Meshing curve 366 (Line)
# Info    : [ 80%] Meshing curve 290 (Line)
# Info    : [ 80%] Meshing curve 402 (Line)
# Info    : [ 90%] Meshing curve 283 (Line)
# Info    : [ 90%] Meshing curve 346 (Line)
# Info    : [ 90%] Meshing curve 281 (Line)
# Info    : [ 90%] Meshing curve 284 (Line)
# Info    : [ 90%] Meshing curve 367 (Line)
# Info    : [ 90%] Meshing curve 291 (Line)
# Info    : [ 90%] Meshing curve 292 (Line)
# Info    : [ 90%] Meshing curve 279 (Line)
# Info    : [ 90%] Meshing curve 278 (Line)
# Info    : [ 90%] Meshing curve 368 (Line)
# Info    : [ 90%] Meshing curve 277 (Line)
# Info    : [ 90%] Meshing curve 276 (Line)
# Info    : [ 90%] Meshing curve 275 (Line)
# Info    : [ 90%] Meshing curve 274 (Line)
# Info    : [ 90%] Meshing curve 334 (Line)
# Info    : [ 90%] Meshing curve 273 (Line)
# Info    : [ 90%] Meshing curve 347 (Line)
# Info    : [ 90%] Meshing curve 348 (Line)
# Info    : [ 90%] Meshing curve 343 (Line)
# Info    : [ 90%] Meshing curve 335 (Line)
# Info    : [ 90%] Meshing curve 342 (Line)
# Info    : [ 90%] Meshing curve 369 (Line)
# Info    : [100%] Meshing curve 341 (Line)
# Info    : [100%] Meshing curve 336 (Line)
# Info    : [100%] Meshing curve 340 (Line)
# Info    : [100%] Meshing curve 339 (Line)
# Info    : [100%] Meshing curve 370 (Line)
# Info    : [100%] Meshing curve 337 (Line)
# Info    : [100%] Meshing curve 371 (Line)
# Info    : [100%] Meshing curve 344 (Line)
# Info    : [100%] Meshing curve 338 (Line)
# Info    : [100%] Meshing curve 375 (Line)
# Info    : [100%] Meshing curve 374 (Line)
# Info    : [100%] Meshing curve 372 (Line)
# Info    : [100%] Meshing curve 373 (Line)
# Info    : Done meshing 1D (Wall 0.0137101s, CPU 0.083455s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 121 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 96 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 109 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 133 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 157 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 169 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 145 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 97 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 134 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 110 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 146 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 111 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 122 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 135 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 147 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 112 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 148 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 113 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 149 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 123 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 136 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 150 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 124 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 137 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 114 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 151 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 125 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 115 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 89 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 152 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 116 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 117 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 153 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 138 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 118 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 154 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 119 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 155 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 120 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 90 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 139 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 140 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 126 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 132 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 131 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 127 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 130 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 141 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 129 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 128 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 144 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 158 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 142 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 143 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 156 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 167 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 159 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 166 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 165 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 164 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 160 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 163 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 162 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 161 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 179 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 180 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 177 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 176 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 175 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 174 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 173 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 172 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 98 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 168 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 99 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 100 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 101 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 102 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 103 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 104 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 105 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 178 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 106 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 107 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 108 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 171 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 170 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 95 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 94 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 93 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 91 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 92 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.154978s, CPU 1.01269s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 11 volumes with 1 connected component
# Info    : Input mesh hash 9586f7ad7f0fa888
# Info    : Creating an empty mesh with 6431 vertices
# Info    : Initialization of tet. mesh
# Info    : Delaunay of       6427 points on   2 threads - mesh.nvert: 4
# Info    : Recovering 2697 missing facet(s)
# Info    : Recover Delaunay
# Info    : Steiner(s) point(s) were inserted
# Info    : All volumes of the BRep were found and colorized accordingly
# Info    : Computing interpolated mesh sizes...
# Info    : Done computing interpolated mesh sizes
# Info    : Delaunay of      11481 points on   2 threads - mesh.nvert: 6432
# Info    :           -      10131 points filtered
# Info    :           =       1350 points added
# Info    : Computing interpolated mesh sizes...
# Info    : Done computing interpolated mesh sizes
# Info    : Delaunay of      10306 points on   2 threads - mesh.nvert: 7782
# Info    :           -       7620 points filtered
# Info    :           =       2686 points added
# Info    : Computing interpolated mesh sizes...
# Info    : Done computing interpolated mesh sizes
# Info    : Delaunay of       7022 points on   2 threads - mesh.nvert: 10468
# Info    :           -       4861 points filtered
# Info    :           =       2161 points added
# Info    : Computing interpolated mesh sizes...
# Info    : Done computing interpolated mesh sizes
# Info    : Delaunay of       1127 points on   1 threads - mesh.nvert: 12629
# Info    :           -        571 points filtered
# Info    :           =        556 points added
# Info    : Computing interpolated mesh sizes...
# Info    : Done computing interpolated mesh sizes
# Info    : Delaunay of         94 points on   1 threads - mesh.nvert: 13185
# Info    :           -         26 points filtered
# Info    :           =         68 points added
# Info    : Computing interpolated mesh sizes...
# Info    : Done computing interpolated mesh sizes
# Info    : Delaunay of          5 points on   1 threads - mesh.nvert: 13253
# Info    :           -          1 points filtered
# Info    :           =          4 points added
# Info    : Computing interpolated mesh sizes...
# Info    : Done computing interpolated mesh sizes
# Info    : Improving      12456 tet. on   8 thrd (S & ER)
# Info    : Improving      10177 tet. on   8 thrd (S & ER)
# Info    : Improving       9978 tet. on   8 thrd (S & ER)
# Info    : Improving       9902 tet. on   8 thrd (S & ER)
# Info    : Improving       9875 tet. on   8 thrd (S & ER)
# Info    : Improving       9828 tet. on   8 thrd (GSC)
# Info    : Improving       9724 tet. on   8 thrd (S & ER)
# Info    : Improving       9714 tet. on   8 thrd (S & ER)
# Info    : Improving       9710 tet. on   8 thrd (S & ER)
# Info    : Improving       9709 tet. on   8 thrd (GSC)
# Info    : Improving       9707 tet. on   8 thrd (S & ER)
# Info    : Improving       9705 tet. on   8 thrd (S & ER)
# Info    : Improving       9705 tet. on   8 thrd (GSC)
# Info    : Improving       9705 tet. on   8 thrd (S & ER)
# Info    : Improving       9705 tet. on   8 thrd (S & ER)
# Info    : Improving       9705 tet. on   8 thrd (GSC)
# Info    : Improving       9705 tet. on   8 thrd (S & ER)
# Info    :  	Final tet. mesh contains 77094 tetrahedra
# Info    :  	Final tet. mesh contains 13257 vertices
# Info    : tEmptyMesh  	 = 	    0.016
# Info    : tVerifyBnd  	 = 	    0.003
# Info    : tBndRecovery	 = 	    0.031
# Info    : tConvertMesh	 = 	    0.003
# Info    : tRefine     	 = 	    0.037
# Info    : tOptimize   	 = 	    3.334
# Info    : Done meshing 3D (Wall 3.53899s, CPU 18.8731s)
# Info    : 13257 nodes 83566 elements

# %%
gmsh_renderer.launch_gui()
# Out:
# -------------------------------------------------------
# Version       : 4.15.0
# License       : GNU General Public License
# Build OS      : MacOSARM-sdk
# Build date    : 20251026
# Build host    : gmsh.info
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blas[petsc] Blossom Cgns DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack Lapack[petsc] MathEx[contrib] Med Mesh Metis[contrib] Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom PETSc Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] TouchBar Untangle Voro++[contrib] WinslowUntangler Zlib tinyobjloader
# FLTK version  : 1.4.0
# PETSc version : 3.17.4 (real arithmtic)
# OCC version   : 7.8.1
# MED version   : 4.1.0
# Packaged by   : geuzaine
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:5fdfbb75-8128-4d25-b3b5-25e89d85c0b7.png)
# ![image.png](attachment:e484a516-4359-4c4d-93ec-97d70206a07f.png)

# %% [markdown]
# ## Customizing the mesh
# ### Setting initial mesh size parameters

# %%
# Update the mesh options
gmsh_renderer.options.mesh.min_size = "5um"
gmsh_renderer.options.mesh.max_size = "20um"

# Render the design
gmsh_renderer.render_design(
    open_pins=[("Q1", "coupler1"), ("Q1", "coupler2"), ("Q1", "readout")],
    mesh_geoms=False,
)

# Mesh the design (without intelli-mesh)
gmsh_renderer.add_mesh(intelli_mesh=False)
gmsh_renderer.launch_gui()

# %% [markdown]
# ### Using the Intelli-mesh feature in QGmshRenderer

# %%
# Update the mesh options
gmsh_renderer.options.mesh.min_size = "5um"
gmsh_renderer.options.mesh.max_size = "50um"

# Render and mesh the design (with intelli-mesh)
gmsh_renderer.render_design(
    open_pins=[("Q1", "coupler1"), ("Q1", "coupler2"), ("Q1", "readout")],
    mesh_geoms=True,
)
gmsh_renderer.launch_gui()

# %% [markdown]
# ## Saving your mesh to a file

# %%
# Export the Gmsh generated mesh to a file
gmsh_renderer.export_mesh("test.msh")
# Out:
# Info    : Writing 'test.msh'...
# Info    : Done writing 'test.msh'

# %%
# Close the Gmsh renderer
gmsh_renderer.close()

# %%
# %metal_heading 3. Rendering your design in `QElmerRenderer` (uses `QGmshRenderer`)
# Out:
#     <h1 style="
#         background: #12c2e9;  /* fallback for old browsers */
#         background: -webkit-linear-gradient(to right, #d4418e 0%, #0652c5 74%);  /* Chrome 10-25, Safari 5.1-6 */
#         background: linear-gradient(315deg, #d4418e 0%, #0652c5 74%); /* W3C, IE 10+/ Edge, Firefox 16+, Chrome 26+, Opera 12+, Safari 7+ */
#         margin-top: 50px;
#         border-style: outset;
#         padding-top:100px;
#         padding-bottom:50px;
#         padding-left:25px;
#         color: white;
#     "> 3. Rendering your design in `QElmerRenderer` (uses `QGmshRenderer`) <h1>

# %%
# Instantiate the Elmer renderer
elmer_renderer = QElmerRenderer(design)

# Elmer renderer uses the Gmsh renderer to
# generate a mesh for the design
# Set initial parameters for meshing in Gmsh (IMPORTANT step!!)
elmer_renderer.gmsh.options.mesh.min_size = "5um"
elmer_renderer.gmsh.options.mesh.max_size = "50um"
# Out:
# Warning : Gmsh has aleady been initialized

# %%
# Render the design
elmer_renderer.render_design(
    open_pins=[("Q1", "coupler1"), ("Q1", "coupler2"), ("Q1", "readout")],
    skip_junctions=True,
)
# Out:
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...nts - Checking SD faces
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [  0%] Meshing curve 192 (Line)
# Info    : [  0%] Meshing curve 219 (Line)
# Info    : [  0%] Meshing curve 246 (Line)
# Info    : [  0%] Meshing curve 137 (Line)
# Info    : [  0%] Meshing curve 300 (Line)
# Info    : [  0%] Meshing curve 165 (Line)
# Info    : [  0%] Meshing curve 247 (Line)
# Info    : [  0%] Meshing curve 273 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 220 (Line)
# Info    : [ 10%] Meshing curve 193 (Line)
# Info    : [ 10%] Meshing curve 248 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 10%] Meshing curve 249 (Line)
# Info    : [ 10%] Meshing curve 221 (Line)
# Info    : [ 10%] Meshing curve 194 (Line)
# Info    : [ 10%] Meshing curve 301 (Line)
# Info    : [ 10%] Meshing curve 250 (Line)
# Info    : [ 10%] Meshing curve 251 (Line)
# Info    : [ 10%] Meshing curve 195 (Line)
# Info    : [ 10%] Meshing curve 222 (Line)
# Info    : [ 10%] Meshing curve 274 (Line)
# Info    : [ 10%] Meshing curve 138 (Line)
# Info    : [ 10%] Meshing curve 252 (Line)
# Info    : [ 10%] Meshing curve 223 (Line)
# Info    : [ 10%] Meshing curve 196 (Line)
# Info    : [ 10%] Meshing curve 302 (Line)
# Info    : [ 10%] Meshing curve 253 (Line)
# Info    : [ 10%] Meshing curve 224 (Line)
# Info    : [ 10%] Meshing curve 197 (Line)
# Info    : [ 10%] Meshing curve 254 (Line)
# Info    : [ 10%] Meshing curve 198 (Line)
# Info    : [ 10%] Meshing curve 303 (Line)
# Info    : [ 10%] Meshing curve 199 (Line)
# Info    : [ 20%] Meshing curve 4 (Line)
# Info    : [ 20%] Meshing curve 275 (Line)
# Info    : [ 20%] Meshing curve 200 (Line)
# Info    : [ 20%] Meshing curve 201 (Line)
# Info    : [ 20%] Meshing curve 139 (Line)
# Info    : [ 20%] Meshing curve 202 (Line)
# Info    : [ 20%] Meshing curve 203 (Line)
# Info    : [ 20%] Meshing curve 5 (Line)
# Info    : [ 20%] Meshing curve 204 (Line)
# Info    : [ 20%] Meshing curve 276 (Line)
# Info    : [ 20%] Meshing curve 205 (Line)
# Info    : [ 20%] Meshing curve 304 (Line)
# Info    : [ 20%] Meshing curve 140 (Line)
# Info    : [ 20%] Meshing curve 206 (Line)
# Info    : [ 20%] Meshing curve 207 (Line)
# Info    : [ 20%] Meshing curve 208 (Line)
# Info    : [ 20%] Meshing curve 277 (Line)
# Info    : [ 20%] Meshing curve 141 (Line)
# Info    : [ 20%] Meshing curve 305 (Line)
# Info    : [ 30%] Meshing curve 6 (Line)
# Info    : [ 30%] Meshing curve 306 (Line)
# Info    : [ 30%] Meshing curve 278 (Line)
# Info    : [ 30%] Meshing curve 7 (Line)
# Info    : [ 30%] Meshing curve 142 (Line)
# Info    : [ 30%] Meshing curve 307 (Line)
# Info    : [ 30%] Meshing curve 279 (Line)
# Info    : [ 30%] Meshing curve 8 (Line)
# Info    : [ 30%] Meshing curve 280 (Line)
# Info    : [ 30%] Meshing curve 308 (Line)
# Info    : [ 30%] Meshing curve 9 (Line)
# Info    : [ 30%] Meshing curve 281 (Line)
# Info    : [ 30%] Meshing curve 309 (Line)
# Info    : [ 30%] Meshing curve 10 (Line)
# Info    : [ 30%] Meshing curve 282 (Line)
# Info    : [ 30%] Meshing curve 143 (Line)
# Info    : [ 30%] Meshing curve 310 (Line)
# Info    : [ 30%] Meshing curve 11 (Line)
# Info    : [ 30%] Meshing curve 283 (Line)
# Info    : [ 40%] Meshing curve 12 (Line)
# Info    : [ 40%] Meshing curve 311 (Line)
# Info    : [ 40%] Meshing curve 284 (Line)
# Info    : [ 40%] Meshing curve 121 (Line)
# Info    : [ 40%] Meshing curve 144 (Line)
# Info    : [ 40%] Meshing curve 285 (Line)
# Info    : [ 40%] Meshing curve 312 (Line)
# Info    : [ 40%] Meshing curve 122 (Line)
# Info    : [ 40%] Meshing curve 286 (Line)
# Info    : [ 40%] Meshing curve 123 (Line)
# Info    : [ 40%] Meshing curve 313 (Line)
# Info    : [ 40%] Meshing curve 287 (Line)
# Info    : [ 40%] Meshing curve 145 (Line)
# Info    : [ 40%] Meshing curve 124 (Line)
# Info    : [ 40%] Meshing curve 314 (Line)
# Info    : [ 40%] Meshing curve 288 (Line)
# Info    : [ 40%] Meshing curve 125 (Line)
# Info    : [ 40%] Meshing curve 289 (Line)
# Info    : [ 40%] Meshing curve 315 (Line)
# Info    : [ 40%] Meshing curve 146 (Line)
# Info    : [ 40%] Meshing curve 290 (Line)
# Info    : [ 40%] Meshing curve 126 (Line)
# Info    : [ 40%] Meshing curve 291 (Line)
# Info    : [ 40%] Meshing curve 147 (Line)
# Info    : [ 40%] Meshing curve 292 (Line)
# Info    : [ 40%] Meshing curve 293 (Line)
# Info    : [ 40%] Meshing curve 316 (Line)
# Info    : [ 40%] Meshing curve 148 (Line)
# Info    : [ 40%] Meshing curve 294 (Line)
# Info    : [ 50%] Meshing curve 127 (Line)
# Info    : [ 50%] Meshing curve 295 (Line)
# Info    : [ 50%] Meshing curve 149 (Line)
# Info    : [ 50%] Meshing curve 166 (Line)
# Info    : [ 50%] Meshing curve 296 (Line)
# Info    : [ 50%] Meshing curve 150 (Line)
# Info    : [ 50%] Meshing curve 297 (Line)
# Info    : [ 50%] Meshing curve 151 (Line)
# Info    : [ 50%] Meshing curve 298 (Line)
# Info    : [ 50%] Meshing curve 128 (Line)
# Info    : [ 50%] Meshing curve 317 (Line)
# Info    : [ 50%] Meshing curve 152 (Line)
# Info    : [ 50%] Meshing curve 299 (Line)
# Info    : [ 50%] Meshing curve 325 (Line)
# Info    : [ 50%] Meshing curve 153 (Line)
# Info    : [ 50%] Meshing curve 326 (Line)
# Info    : [ 50%] Meshing curve 154 (Line)
# Info    : [ 50%] Meshing curve 318 (Line)
# Info    : [ 50%] Meshing curve 324 (Line)
# Info    : [ 60%] Meshing curve 129 (Line)
# Info    : [ 60%] Meshing curve 225 (Line)
# Info    : [ 60%] Meshing curve 155 (Line)
# Info    : [ 60%] Meshing curve 323 (Line)
# Info    : [ 60%] Meshing curve 156 (Line)
# Info    : [ 60%] Meshing curve 226 (Line)
# Info    : [ 60%] Meshing curve 322 (Line)
# Info    : [ 60%] Meshing curve 130 (Line)
# Info    : [ 60%] Meshing curve 157 (Line)
# Info    : [ 60%] Meshing curve 321 (Line)
# Info    : [ 60%] Meshing curve 319 (Line)
# Info    : [ 60%] Meshing curve 131 (Line)
# Info    : [ 60%] Meshing curve 132 (Line)
# Info    : [ 60%] Meshing curve 133 (Line)
# Info    : [ 60%] Meshing curve 320 (Line)
# Info    : [ 60%] Meshing curve 134 (Line)
# Info    : [ 60%] Meshing curve 136 (Line)
# Info    : [ 70%] Meshing curve 135 (Line)
# Info    : [ 70%] Meshing curve 164 (Line)
# Info    : [ 70%] Meshing curve 163 (Line)
# Info    : [ 70%] Meshing curve 162 (Line)
# Info    : [ 70%] Meshing curve 161 (Line)
# Info    : [ 70%] Meshing curve 160 (Line)
# Info    : [ 70%] Meshing curve 159 (Line)
# Info    : [ 70%] Meshing curve 158 (Line)
# Info    : [ 70%] Meshing curve 186 (Line)
# Info    : [ 70%] Meshing curve 182 (Line)
# Info    : [ 70%] Meshing curve 255 (Line)
# Info    : [ 70%] Meshing curve 256 (Line)
# Info    : [ 70%] Meshing curve 179 (Line)
# Info    : [ 70%] Meshing curve 180 (Line)
# Info    : [ 70%] Meshing curve 183 (Line)
# Info    : [ 70%] Meshing curve 181 (Line)
# Info    : [ 70%] Meshing curve 167 (Line)
# Info    : [ 70%] Meshing curve 168 (Line)
# Info    : [ 70%] Meshing curve 169 (Line)
# Info    : [ 70%] Meshing curve 170 (Line)
# Info    : [ 70%] Meshing curve 171 (Line)
# Info    : [ 70%] Meshing curve 172 (Line)
# Info    : [ 70%] Meshing curve 187 (Line)
# Info    : [ 70%] Meshing curve 188 (Line)
# Info    : [ 80%] Meshing curve 178 (Line)
# Info    : [ 80%] Meshing curve 177 (Line)
# Info    : [ 80%] Meshing curve 176 (Line)
# Info    : [ 80%] Meshing curve 175 (Line)
# Info    : [ 80%] Meshing curve 174 (Line)
# Info    : [ 80%] Meshing curve 209 (Line)
# Info    : [ 80%] Meshing curve 257 (Line)
# Info    : [ 80%] Meshing curve 258 (Line)
# Info    : [ 80%] Meshing curve 259 (Line)
# Info    : [ 80%] Meshing curve 260 (Line)
# Info    : [ 80%] Meshing curve 261 (Line)
# Info    : [ 80%] Meshing curve 227 (Line)
# Info    : [ 80%] Meshing curve 228 (Line)
# Info    : [ 80%] Meshing curve 229 (Line)
# Info    : [ 80%] Meshing curve 230 (Line)
# Info    : [ 80%] Meshing curve 231 (Line)
# Info    : [ 80%] Meshing curve 173 (Line)
# Info    : [ 80%] Meshing curve 217 (Line)
# Info    : [ 80%] Meshing curve 232 (Line)
# Info    : [ 80%] Meshing curve 218 (Line)
# Info    : [ 80%] Meshing curve 233 (Line)
# Info    : [ 90%] Meshing curve 216 (Line)
# Info    : [ 90%] Meshing curve 234 (Line)
# Info    : [ 90%] Meshing curve 215 (Line)
# Info    : [ 90%] Meshing curve 214 (Line)
# Info    : [ 90%] Meshing curve 210 (Line)
# Info    : [ 90%] Meshing curve 213 (Line)
# Info    : [ 90%] Meshing curve 235 (Line)
# Info    : [ 90%] Meshing curve 212 (Line)
# Info    : [ 90%] Meshing curve 236 (Line)
# Info    : [ 90%] Meshing curve 211 (Line)
# Info    : [ 90%] Meshing curve 237 (Line)
# Info    : [ 90%] Meshing curve 238 (Line)
# Info    : [ 90%] Meshing curve 245 (Line)
# Info    : [ 90%] Meshing curve 244 (Line)
# Info    : [ 90%] Meshing curve 243 (Line)
# Info    : [ 90%] Meshing curve 242 (Line)
# Info    : [ 90%] Meshing curve 241 (Line)
# Info    : [ 90%] Meshing curve 240 (Line)
# Info    : [ 90%] Meshing curve 239 (Line)
# Info    : [ 90%] Meshing curve 189 (Line)
# Info    : [ 90%] Meshing curve 271 (Line)
# Info    : [ 90%] Meshing curve 272 (Line)
# Info    : [ 90%] Meshing curve 269 (Line)
# Info    : [ 90%] Meshing curve 270 (Line)
# Info    : [ 90%] Meshing curve 268 (Line)
# Info    : [ 90%] Meshing curve 267 (Line)
# Info    : [ 90%] Meshing curve 266 (Line)
# Info    : [ 90%] Meshing curve 184 (Line)
# Info    : [100%] Meshing curve 265 (Line)
# Info    : [100%] Meshing curve 264 (Line)
# Info    : [100%] Meshing curve 190 (Line)
# Info    : [100%] Meshing curve 191 (Line)
# Info    : [100%] Meshing curve 263 (Line)
# Info    : [100%] Meshing curve 262 (Line)
# Info    : [100%] Meshing curve 185 (Line)
# Info    : Done meshing 1D (Wall 0.194083s, CPU 1.26943s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 72 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 84 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 60 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 96 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 120 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 108 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 85 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 132 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 109 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 97 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 86 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 98 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 87 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 99 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 100 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 88 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 101 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 102 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 61 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 103 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 104 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 89 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 105 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 90 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 91 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 92 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 62 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 93 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 94 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 95 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 107 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 106 (Plane, Frontal-Delaunay)
# Info    : [  0%] Meshing surface 63 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 64 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 121 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 110 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 111 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 112 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 122 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 113 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 114 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 115 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 116 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 119 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 118 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 117 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 53 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 130 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 131 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 129 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 128 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 127 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 126 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 125 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 124 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 133 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 123 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 142 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 143 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 140 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 141 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 139 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 138 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 137 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 136 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 135 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 134 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 59 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 58 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 57 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 56 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 55 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 54 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 71 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 70 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 69 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 65 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 68 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 67 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 66 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 82 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 83 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 80 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 81 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 79 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 78 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 77 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 76 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 75 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 74 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 73 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.531887s, CPU 3.59788s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 11 volumes with 1 connected component
# Info    : Input mesh hash 40d8f8ccfa4cf517
# Info    : Creating an empty mesh with 21836 vertices
# Info    : Initialization of tet. mesh
# Info    : Delaunay of      21832 points on   8 threads - mesh.nvert: 4
# Info    : Recovering 3801 missing facet(s)
# Info    : Recover Delaunay
# Info    : All volumes of the BRep were found and colorized accordingly
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Delaunay of      48418 points on   8 threads - mesh.nvert: 21836
# Info    :           -      45850 points filtered
# Info    :           =       2568 points added
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Delaunay of      46622 points on   8 threads - mesh.nvert: 24404
# Info    :           -      39009 points filtered
# Info    :           =       7613 points added
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Delaunay of      43695 points on   8 threads - mesh.nvert: 32017
# Info    :           -      32885 points filtered
# Info    :           =      10810 points added
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Delaunay of      18466 points on   8 threads - mesh.nvert: 42827
# Info    :           -      12200 points filtered
# Info    :           =       6266 points added
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Delaunay of       3028 points on   1 threads - mesh.nvert: 49093
# Info    :           -       1452 points filtered
# Info    :           =       1576 points added
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Delaunay of        261 points on   1 threads - mesh.nvert: 50669
# Info    :           -         71 points filtered
# Info    :           =        190 points added
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Delaunay of         15 points on   1 threads - mesh.nvert: 50859
# Info    :           -          2 points filtered
# Info    :           =         13 points added
# Info    : Computing mesh sizes...
# Info    : Done computing mesh sizes
# Info    : Improving      27754 tet. on   8 thrd (S & ER)
# Info    : Improving      16637 tet. on   8 thrd (S & ER)
# Info    : Improving      16290 tet. on   8 thrd (S & ER)
# Info    : Improving      16264 tet. on   8 thrd (GSC)
# Info    : Improving      16106 tet. on   8 thrd (S & ER)
# Info    : Improving      16108 tet. on   8 thrd (S & ER)
# Info    : Improving      16110 tet. on   8 thrd (S & ER)
# Info    : Improving      16109 tet. on   8 thrd (GSC)
# Info    : Improving      16102 tet. on   8 thrd (S & ER)
# Info    : Improving      16101 tet. on   8 thrd (S & ER)
# Info    : Improving      16102 tet. on   8 thrd (GSC)
# Info    : Improving      16099 tet. on   8 thrd (S & ER)
# Info    :  	Final tet. mesh contains 302865 tetrahedra
# Info    :  	Final tet. mesh contains 50872 vertices
# Info    : tEmptyMesh  	 = 	    0.056
# Info    : tVerifyBnd  	 = 	    0.005
# Info    : tBndRecovery	 = 	    0.105
# Info    : tConvertMesh	 = 	    0.007
# Info    : tRefine     	 = 	    0.736
# Info    : tOptimize   	 = 	    4.441
# Info    : Done meshing 3D (Wall 6.00735s, CPU 31.5646s)
# Info    : 50872 nodes 336588 elements

# %%
# View the generated mesh
elmer_renderer.launch_gmsh_gui()

# %%
# Export the generated mesh
elmer_renderer.export_mesh()
# Out:
# Info    : Writing 'out.msh'...
# Info    : Done writing 'out.msh'

# %%
# Add a solution setup to solve for the capacitance matrix
elmer_renderer.add_solution_setup("capacitance")

# %%
# Run the simulation in ElmerFEM
elmer_renderer.run("capacitance")
# Out:
# 03:07AM 31s INFO [run]: Running ElmerGrid on input mesh from Gmsh...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Run the simulation in ElmerFEM
# ----> 2 elmer_renderer.run("capacitance")
#
# File ~/CODE_REPOS/quantum_hardware/qiskit-metal/src/qiskit_metal/renderers/renderer_elmer/elmer_renderer.py:448, in QElmerRenderer.run(self, sim_type, display_cap_matrix)
#     443     cap_matrix_file = os.path.join(
#     444         self._options["simulation_dir"], setup["Capacitance_Matrix_Filename"]
#     445     )
#     447 self.logger.info("Running ElmerGrid on input mesh from Gmsh...")
# --> 448 self._elmer_runner.run_elmergrid(sim_dir, meshfile)
#     449 self.logger.info(f"Running ElmerSolver for solver type: '{sim_type}'")
#     450 self._elmer_runner.run_elmersolver(sim_dir, sif_name)
#
# File ~/CODE_REPOS/quantum_hardware/qiskit-metal/src/qiskit_metal/renderers/renderer_elmer/elmer_runner.py:585, in ElmerRunner.run_elmergrid(self, sim_dir, meshfile, elmergrid, options)
#     583 args = [elmergrid, "14", "2", os.path.join("..", meshfile)] + options
#     584 with open(os.path.join(sim_dir, "elmergrid.log"), "w+", encoding="utf-8") as f:
# --> 585     subprocess.run(args, cwd=sim_dir, stdout=f, stderr=f)
#     587 mesh_dir = meshfile.split(".")[-2]
#     588 files = os.listdir(mesh_dir)
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1953     err_msg = os.strerror(errno_num)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#    1957     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ElmerGrid'

# %%
# Display the capacitnce matrix obtained after the simulation
elmer_renderer.capacitance_matrix

# %%
# Run this, and in the Gmsh window,
# Right click on an empty area, click on "Toggle mesh visibility"
# Next, go to: Tools -> Visibility, select "Physical groups" in drop down menu
# Select "Volume 2", click on apply
# On the left pane, click on "Post-processing", and select the views that you want to observe
elmer_renderer.display_post_processing_data()

# %%
# Export the capacitance matrix
elmer_renderer.save_capacitance_matrix("cap_matrix.txt")

# Close the elmer renderer
elmer_renderer.close()

# %%
# %metal_heading 4. Perform LOM 2.0 Analysis

# %%
# Import necessary things for LOM 2.0 Analysis
import numpy as np
from qiskit_metal.analyses.quantization.lom_core_analysis import (
    CompositeSystem,
    Cell,
    Subsystem,
)
from scipy.constants import speed_of_light as c_light
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Load the saved capacitance matrix
cap_matrix = load_capacitance_matrix_from_file("cap_matrix.txt")

# %%
# Define cells
opt1 = dict(
    node_rename={
        "Q1_coupler1_connector_pad": "coupler1",
        "Q1_coupler2_connector_pad": "coupler2",
        "Q1_readout_connector_pad": "readout",
    },
    cap_mat=cap_matrix,
    ind_dict={("Q1_pad_top", "Q1_pad_bot"): 12},  # junction inductance in nH
    jj_dict={("Q1_pad_top", "Q1_pad_bot"): "j1"},
    cj_dict={("Q1_pad_top", "Q1_pad_bot"): 2},  # junction capacitance in fF
)
cell_1 = Cell(opt1)

# %%
# Define subsystems
# subsystem 1: Transmon
transmon = Subsystem(name="transmon1_sys", sys_type="TRANSMON", nodes=["j1"])

# subsystem 2: Coupler 1
q_opts = dict(
    f_res=7.4,  # resonator dressed frequency in GHz
    Z0=50,  # characteristic impedance in Ohm
    vp=0.404314 * c_light,  # phase velocity
)
coup1 = Subsystem(
    name="coup1_sys", sys_type="TL_RESONATOR", nodes=["coupler1"], q_opts=q_opts
)

# subsystem 3: Coupler 2
q_opts = dict(
    f_res=7.2,  # resonator dressed frequency in GHz
    Z0=50,  # characteristic impedance in Ohm
    vp=0.404314 * c_light,  # phase velocity
)
coup2 = Subsystem(
    name="coup2_sys", sys_type="TL_RESONATOR", nodes=["coupler2"], q_opts=q_opts
)

# subsystem 4: Readout
q_opts = dict(
    f_res=7,  # resonator dressed frequency in GHz
    Z0=50,  # characteristic impedance in Ohm
    vp=0.404314 * c_light,  # phase velocity
)
readout = Subsystem(
    name="readout_sys", sys_type="TL_RESONATOR", nodes=["readout"], q_opts=q_opts
)

# %%
# Define the composite system
composite_sys = CompositeSystem(
    subsystems=[transmon, coup1, coup2, readout],
    cells=[cell_1],
    grd_node="ground_plane",
    nodes_force_keep=["coupler1", "coupler2", "readout"],
)

# %%
# Get the circuit graph object
cg = composite_sys.circuitGraph()
print(cg)

# %%
# Create a hilbert space with the composite system
hilbertspace = composite_sys.create_hilbertspace()
print(hilbertspace)

# %%
# Add interaction between the subsystems
hilbertspace = composite_sys.add_interaction()

# Get the total hamiltonian of the composite system
hilbertspace.hamiltonian()

# %%
# Get the reults from the hamiltonian
# Qubit frequency
# Chi matrix (having anharmonicity and readout chi values)
hamiltonian_results = composite_sys.hamiltonian_results(hilbertspace, evals_count=30)

# %%
chi_df = hamiltonian_results["chi_in_MHz"].to_dataframe()
print(
    "Transmon frequency     :", hamiltonian_results["fQ_in_Ghz"]["transmon1_sys"], "GHz"
)
print("Transmon Anharmonicity :", chi_df["transmon1_sys"]["transmon1_sys"], "MHz")
print("Readou chi             :", chi_df["readout_sys"]["transmon1_sys"], "MHz")

# %%
# Get the coupling 'g' values between qubit and resonators
composite_sys.compute_gs().to_dataframe()

# %%
# Hamiltonian parameters for the transmon
transmon.h_params

# %%
# Close the Qiskit Metal GUI
gui.main_window.close()
