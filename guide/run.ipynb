# %%
# %load_ext autoreload
# %autoreload 2
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs

# %metal_heading Welcome to Qiskit Metal!
design = designs.DesignPlanar()
gui = MetalGUI(design)

#from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket


#q1 = TransmonPocket(design, 'Q1', options=dict(connection_pads=dict(a=dict()))) # Create a new Transmon Pocket object with name 'Q1' 
#gui.rebuild()  # rebuild the design and plot
# Out:
#     <h1 style="
#         background: #12c2e9;  /* fallback for old browsers */
#         background: -webkit-linear-gradient(to right, #d4418e 0%, #0652c5 74%);  /* Chrome 10-25, Safari 5.1-6 */
#         background: linear-gradient(315deg, #d4418e 0%, #0652c5 74%); /* W3C, IE 10+/ Edge, Firefox 16+, Chrome 26+, Opera 12+, Safari 7+ */
#         margin-top: 50px;
#         border-style: outset;
#         padding-top:100px;
#         padding-bottom:50px;
#         padding-left:25px;
#         color: white;
#     "> Welcome to Qiskit Metal! <h1>
# hi
# qmodelindex: filename:  transmon_pocket_cl.py index:  <PySide2.QtCore.QModelIndex(2,0,0x7fe7ffd2f300,LibraryFileProxyModel(0x7fe7fb2acc20))  at 0x7fe801786be0>
# manolo
# full path:  /Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/qlibrary/qubits/transmon_pocket_cl.py
# import_class name: TransmonPocketCL
# import_class: <class 'qiskit_metal.qlibrary.qubits.transmon_pocket_cl.TransmonPocketCL'>
# self.logger IS:  <Logger metal (DEBUG)>
# cur_name name
# entry_type: <class 'str'>
# param.default: None
# initting NormalEntryWidget
# cur_name options
# entry_type: <class 'addict.addict.Dict'>
# param.default: None
# initting dictionary entry widget
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fe83212b640>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# entry_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fe83212b9b0>
# cur_name options_connection_pads
# entry_type: <class 'addict.addict.Dict'>
# param.default: None
# initting dictionary entry widget
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fe832130460>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# entry_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fe832130370>
# cur_name make
# entry_type: <class 'bool'>
# param.default: True
# initting NormalEntryWidget
# made it
# param_entry made
# param entry showing? : True
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fe83212b9b0>
# content height 183
# 05:20PM 29s ERROR [wrapper]: Traceback (most recent call last):
#   File "/Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/_gui/widgets/library_new_qcomponent/parameter_entry_scroll_area.py", line 417, in dictionaryentrybox_to_dictionary
#     value = cur_type(strvalue)
# ValueError: invalid literal for int() with base 10: 'asdf'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/_gui/widgets/library_new_qcomponent/parameter_entry_scroll_area.py", line 60, in wrapper
#     func(*args, **kwargs)
#   File "/Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/_gui/widgets/library_new_qcomponent/parameter_entry_scroll_area.py", line 419, in dictionaryentrybox_to_dictionary
#     raise InvalidParameterTypeException(f"The type {cur_type} you chose is not compatible with your input {strvalue}. Error: {e}")
#   File "/Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/_gui/widgets/library_new_qcomponent/parameter_entry_scroll_area.py", line 445, in __init__
#     super().__init__()
# TypeError: __init__() missing 1 required positional argument: 'message'
#
#
# ERROR in PEDA
#
#  module   :  qiskit_metal._gui.widgets.library_new_qcomponent.parameter_entry_scroll_area
#  function :  ParameterEntryScrollArea.QLibraryExceptionDecorator.on_exception_pop_up_warning.<locals>.wrapper
#  err msg  :  TypeError("__init__() missing 1 required positional argument: 'message'")
#  args; kws:  (<qiskit_metal._gui.widgets.library_new_qcomponent.parameter_entry_scroll_area.ParameterEntryScrollArea object at 0x7fe7e81865a0>, <PySide2.QtWidgets.QVBoxLayout object at 0x7fe83212b640>, {}); {}
# Till now I always got by on my own........ (I never really cared until I met you)
# will arg:  name
# Normal
# ed.txt()
# default arg bc
# default arg:  None
# final value:  None
# entry.arg_name:  name
# entry.arg_name type:  <class 'str'>
# will arg:  options
# kv_count:  2
#
# peda key:  asdf
# keyname:  asdf
# value_widget is:  <PySide2.QtWidgets.QLineEdit object at 0x7fe83212bdc0>
# type current txt:  int
# type builtins:  <class 'module'>
# builtins <module 'builtins' (built-in)>
# dict cur_type:  <class 'int'>
# will value
# normal Exceptions __init__() missing 1 required positional argument: 'message'
# args[0]:  <qiskit_metal._gui.widgets.library_new_qcomponent.parameter_entry_scroll_area.ParameterEntryScrollArea object at 0x7fe7e81865a0>
# will arg:  options_connection_pads
# kv_count:  2
#
# peda key:
# kv_dict is:  {}
# will arg:  make
# Normal
# ed.txt()
# default arg bc
# default arg:  True
# final value:  True
# entry.arg_name:  make
# entry.arg_name type:  <class 'str'>
# all args added to kwargs {'name': None, 'options': {}, 'options_connection_pads': {}, 'make': True}
# imported class <class 'qiskit_metal.qlibrary.qubits.transmon_pocket_cl.TransmonPocketCL'>
# imported class:  name:    Q_1
# class:   TransmonPocketCL
# options:
#   'pos_x'             : '0um',
#   'pos_y'             : '0um',
#   'connection_pads'   : {
#                         },
#   'pad_gap'           : '30um',
#   'inductor_width'    : '20um',
#   'pad_width'         : '455um',
#   'pad_height'        : '90um',
#   'pocket_width'      : '650um',
#   'pocket_height'     : '650um',
#   'orientation'       : '0',
#   'make_CL'           : True,
#   'cl_gap'            : '6um',
#   'cl_width'          : '10um',
#   'cl_length'         : '20um',
#   'cl_ground_gap'     : '6um',
#   'cl_pocket_edge'    : '0',
#   'cl_off_center'     : '50um',
#   'hfss_inductance'   : '10nH',
#   'hfss_capacitance'  : 0,
#   'hfss_resistance'   : 0,
#   'hfss_mesh_kw_jj'   : 7e-06,
#   'q3d_inductance'    : '10nH',
#   'q3d_capacitance'   : 0,
#   'q3d_resistance'    : 0,
#   'q3d_mesh_kw_jj'    : 7e-06,
#   'gds_cell_name'     : 'my_other_junction',
# module:  qiskit_metal.qlibrary.qubits.transmon_pocket_cl
# id:      1

# %%
q1.options

# %%
TransmonPocket.options_template
