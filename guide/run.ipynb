# %%
# %load_ext autoreload
# %autoreload 2
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs

# %metal_heading Welcome to Qiskit Metal!
design = designs.DesignPlanar()
gui = MetalGUI(design)

#from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket


#q1 = TransmonPocket(design, 'Q1', options=dict(connection_pads=dict(a=dict()))) # Create a new Transmon Pocket object with name 'Q1' 
#gui.rebuild()  # rebuild the design and plot
# Out:
#     <h1 style="
#         background: #12c2e9;  /* fallback for old browsers */
#         background: -webkit-linear-gradient(to right, #d4418e 0%, #0652c5 74%);  /* Chrome 10-25, Safari 5.1-6 */
#         background: linear-gradient(315deg, #d4418e 0%, #0652c5 74%); /* W3C, IE 10+/ Edge, Firefox 16+, Chrome 26+, Opera 12+, Safari 7+ */
#         margin-top: 50px;
#         border-style: outset;
#         padding-top:100px;
#         padding-bottom:50px;
#         padding-left:25px;
#         color: white;
#     "> Welcome to Qiskit Metal! <h1>
# key: units
#  value: mm
# key: chip
#  value: main
# key: qdesign
#  value: {'variables': {'cpw_width': '10 um', 'cpw_gap': '6 um'}}
# key: PRECISION
#  value: 9
# key: geometry
#  value: {'buffer_resolution': 16, 'buffer_mitre_limit': 5.0}
# key: cpw_width
#  value: 10 um
# key: cpw_gap
#  value: 6 um
# key: Lj
#  value: 10nH
# key: Cj
#  value: 0
# key: _Rj
#  value: 0
# key: max_mesh_length_jj
#  value: 7um
# key: project_path
#  value: None
# key: project_name
#  value: None
# key: design_name
#  value: None
# key: ansys_file_extension
#  value: .aedt
# key: x_buffer_width_mm
#  value: 0.2
# key: y_buffer_width_mm
#  value: 0.2
# key: Lj
#  value: 10nH
# key: Cj
#  value: 0
# key: _Rj
#  value: 0
# key: max_mesh_length_jj
#  value: 7um
# key: project_path
#  value: None
# key: project_name
#  value: None
# key: design_name
#  value: None
# key: ansys_file_extension
#  value: .aedt
# key: x_buffer_width_mm
#  value: 0.2
# key: y_buffer_width_mm
#  value: 0.2
# key: short_segments_to_not_fillet
#  value: True
# key: check_short_segments_by_scaling_fillet
#  value: 2.0
# key: gds_unit
#  value: 1
# key: ground_plane
#  value: True
# key: corners
#  value: circular bend
# key: tolerance
#  value: 0.00001
# key: precision
#  value: 0.000000001
# key: width_LineString
#  value: 10um
# key: path_filename
#  value: ../resources/Fake_Junctions.GDS
# key: junction_pad_overlap
#  value: 5um
# key: max_points
#  value: 199
# key: cheese
#  value: {'datatype': '100', 'shape': '0', 'cheese_0_x': '50um', 'cheese_0_y': '50um', 'cheese_1_radius': '100um', 'view_in_file': {'main': {1: True}}}
# key: no_cheese
#  value: {'datatype': '99', 'buffer': '25um', 'cap_style': '2', 'join_style': '2', 'view_in_file': {'main': {1: True}}}
# key: bounding_box_scale_x
#  value: 1.2
# key: bounding_box_scale_y
#  value: 1.2
# 03:53AM 54s ERROR [log_error]: Traceback (most recent call last):
#   File "/Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/_gui/widgets/library_new_qcomponent/parameter_entry_scroll_area.py", line 107, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/_gui/widgets/library_new_qcomponent/parameter_entry_scroll_area.py", line 378, in get_class
#     raise MissingClassException(f"Unable to find correct module for {class_owner} in {str(members)}")
# qiskit_metal._gui.widgets.library_new_qcomponent.qlibrary_exceptions.MissingClassException: Unable to find correct module for fakey in []
#
#
# ERROR in PEDA
#
#  module   :  qiskit_metal._gui.widgets.library_new_qcomponent.parameter_entry_scroll_area
#  function :  ParameterEntryScrollArea.get_class
#  err msg  :  MissingClassException('Unable to find correct module for fakey in []')
#  args; kws:  (<qiskit_metal._gui.widgets.library_new_qcomponent.parameter_entry_scroll_area.ParameterEntryScrollArea object at 0x7fb18932c7d0>, 'qiskit_metal.qlibrary.qubits.fakey'); {}
# Till now I always got by on my own........ (I never really cared until I met you)
# qmodelindex: filename:  fakey.py index:  <PySide2.QtCore.QModelIndex(0,0,0x7fb114e0aab0,LibraryFileProxyModel(0x7fb114f13860))  at 0x7fb189373280>
# hi
# full path:  /Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/qlibrary/qubits/fakey.py
# ParameterEntryScrollArea should be class: <class 'qiskit_metal._gui.widgets.library_new_qcomponent.parameter_entry_scroll_area.ParameterEntryScrollArea'>
# initting paramentryscrollara
# resized
# new pesa: <qiskit_metal._gui.widgets.library_new_qcomponent.parameter_entry_scroll_area.ParameterEntryScrollArea object at 0x7fb18932c7d0>
# orig style sheet
#
# old stylesheet
#
# <PySide2.QtWidgets.QStyle object at 0x7fb18936efa0>
# should be default style sheet
#
# new pesa : <qiskit_metal._gui.widgets.library_new_qcomponent.parameter_entry_scroll_area.ParameterEntryScrollArea object at 0x7fb18932c7d0>
# about to get class from abd file
# tyring init wrapepr
# rooting dir
# tyring init wrapepr
# will memtup
# init_peda_pop_up_arning LibraryQCom...Exception AS str:  MissingClassException
# init_peda_pop_up_arning LibraryQCom...Exception AS:  MissingClassException
# got class

# %%
from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket

options = dict(
    pad_width = '425 um', 
    pocket_height = '650um',
    connection_pads=dict(  # pin connectors
        a = dict(loc_W=+1,loc_H=+1), 
        b = dict(loc_W=-1,loc_H=+1, pad_height='30um'),
        c = dict(loc_W=+1,loc_H=-1, pad_width='200um'),
        d = dict(loc_W=-1,loc_H=-1, pad_height='50um')
    )
)

q0 = TransmonPocket(design, 'Q0', options = dict(pos_x='-1.0mm', pos_y='-1.0mm', **options))
q1 = TransmonPocket(design, 'Q1', options = dict(pos_x='1.0mm', pos_y='+0.0mm', **options))
q2 = TransmonPocket(design, 'Q2', options = dict(pos_x='-1.0mm', pos_y='0.0mm', **options))

gui.rebuild()
gui.autoscale()

# %%
print("HI")
