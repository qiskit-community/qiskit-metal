# %%
# %load_ext autoreload
# %autoreload 2
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs

# %metal_heading Welcome to Qiskit Metal!
design = designs.DesignPlanar()
gui = MetalGUI(design)

#from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket


#q1 = TransmonPocket(design, 'Q1', options=dict(connection_pads=dict(a=dict()))) # Create a new Transmon Pocket object with name 'Q1' 
#gui.rebuild()  # rebuild the design and plot
# Out:
#     <h1 style="
#         background: #12c2e9;  /* fallback for old browsers */
#         background: -webkit-linear-gradient(to right, #d4418e 0%, #0652c5 74%);  /* Chrome 10-25, Safari 5.1-6 */
#         background: linear-gradient(315deg, #d4418e 0%, #0652c5 74%); /* W3C, IE 10+/ Edge, Firefox 16+, Chrome 26+, Opera 12+, Safari 7+ */
#         margin-top: 50px;
#         border-style: outset;
#         padding-top:100px;
#         padding-bottom:50px;
#         padding-left:25px;
#         color: white;
#     "> Welcome to Qiskit Metal! <h1>
# hi
# qmodelindex: filename:  transmon_pocket.py index:  <PySide2.QtCore.QModelIndex(3,0,0x7fc1a8c41530,LibraryFileProxyModel(0x7fc20844f970))  at 0x7fc2312df2d0>
# manolo
# full path:  /Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/qlibrary/qubits/transmon_pocket.py
# resized
# about to get class from abd file
# tyring init wrapepr
# rooting dir
# tyring init wrapepr
# returning imported
# got class
# import_class name: TransmonPocket
# import_class: <class 'qiskit_metal.qlibrary.qubits.transmon_pocket.TransmonPocket'>
# self.logger IS:  <Logger metal (DEBUG)>
# tyring init wrapepr
# cur_name name
# entry_type: <class 'str'>
# param.default: None
# initting NormalEntryWidget
# cur_name options
# entry_type: <class 'addict.addict.Dict'>
# param.default: None
# initting dictionary entry widget
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc23165b370>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# entry_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc23165b6e0>
# cur_name options_connection_pads
# entry_type: <class 'addict.addict.Dict'>
# param.default: None
# initting dictionary entry widget
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc23165d190>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# entry_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc23165d0a0>
# cur_name make
# entry_type: <class 'bool'>
# param.default: True
# initting NormalEntryWidget
# made it
# param_entry made
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc23165b6e0>
# content height 166
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc23165d0a0>
# content height 166
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc23165d0a0>
# content height 166
# hi
# qmodelindex: filename:  transmon_pocket_cl.py index:  <PySide2.QtCore.QModelIndex(2,0,0x7fc1a8c41530,LibraryFileProxyModel(0x7fc20844f970))  at 0x7fc231064550>
# manolo
# full path:  /Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/qlibrary/qubits/transmon_pocket_cl.py
# resized
# about to get class from abd file
# tyring init wrapepr
# rooting dir
# tyring init wrapepr
# returning imported
# got class
# import_class name: TransmonPocketCL
# import_class: <class 'qiskit_metal.qlibrary.qubits.transmon_pocket_cl.TransmonPocketCL'>
# self.logger IS:  <Logger metal (DEBUG)>
# tyring init wrapepr
# cur_name name
# entry_type: <class 'str'>
# param.default: None
# initting NormalEntryWidget
# cur_name options
# entry_type: <class 'addict.addict.Dict'>
# param.default: None
# initting dictionary entry widget
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc23163f140>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# entry_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc23163f870>
# cur_name options_connection_pads
# entry_type: <class 'addict.addict.Dict'>
# param.default: None
# initting dictionary entry widget
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c30870>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# entry_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c30780>
# cur_name make
# entry_type: <class 'bool'>
# param.default: True
# initting NormalEntryWidget
# made it
# param_entry made
# hi
# qmodelindex: filename:  transmon_pocket_cl.py index:  <PySide2.QtCore.QModelIndex(2,0,0x7fc1a8c41530,LibraryFileProxyModel(0x7fc20844f970))  at 0x7fc240feb370>
# manolo
# full path:  /Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/qlibrary/qubits/transmon_pocket_cl.py
# resized
# about to get class from abd file
# tyring init wrapepr
# rooting dir
# tyring init wrapepr
# returning imported
# got class
# import_class name: TransmonPocketCL
# import_class: <class 'qiskit_metal.qlibrary.qubits.transmon_pocket_cl.TransmonPocketCL'>
# self.logger IS:  <Logger metal (DEBUG)>
# tyring init wrapepr
# cur_name name
# entry_type: <class 'str'>
# param.default: None
# initting NormalEntryWidget
# cur_name options
# entry_type: <class 'addict.addict.Dict'>
# param.default: None
# initting dictionary entry widget
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c33aa0>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# entry_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c339b0>
# cur_name options_connection_pads
# entry_type: <class 'addict.addict.Dict'>
# param.default: None
# initting dictionary entry widget
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c36640>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# entry_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c36550>
# cur_name make
# entry_type: <class 'bool'>
# param.default: True
# initting NormalEntryWidget
# made it
# param_entry made
# hi
# qmodelindex: filename:  transmon_pocket_cl.py index:  <PySide2.QtCore.QModelIndex(2,0,0x7fc1a8c41530,LibraryFileProxyModel(0x7fc20844f970))  at 0x7fc243c33820>
# manolo
# full path:  /Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/qlibrary/qubits/transmon_pocket_cl.py
# resized
# about to get class from abd file
# tyring init wrapepr
# rooting dir
# tyring init wrapepr
# returning imported
# got class
# import_class name: TransmonPocketCL
# import_class: <class 'qiskit_metal.qlibrary.qubits.transmon_pocket_cl.TransmonPocketCL'>
# self.logger IS:  <Logger metal (DEBUG)>
# tyring init wrapepr
# cur_name name
# entry_type: <class 'str'>
# param.default: None
# initting NormalEntryWidget
# cur_name options
# entry_type: <class 'addict.addict.Dict'>
# param.default: None
# initting dictionary entry widget
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c38b90>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# entry_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c38aa0>
# cur_name options_connection_pads
# entry_type: <class 'addict.addict.Dict'>
# param.default: None
# initting dictionary entry widget
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c39aa0>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# entry_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c399b0>
# cur_name make
# entry_type: <class 'bool'>
# param.default: True
# initting NormalEntryWidget
# made it
# param_entry made
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c38aa0>
# content height 166
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c38aa0>
# content height 166
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c38aa0>
# content height 166
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c38aa0>
# content height 166
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c399b0>
# content height 166
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c399b0>
# content height 166
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c399b0>
# content height 166
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c399b0>
# content height 166
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c399b0>
# content height 166
# wig lay <PySide2.QtWidgets.QVBoxLayout object at 0x7fc243c399b0>
# content height 166

# %%
q1.options

# %%
TransmonPocket.options_template
