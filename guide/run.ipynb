# %%
# %load_ext autoreload
# %autoreload 2
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs

# %metal_heading Welcome to Qiskit Metal!
design = designs.DesignPlanar()
gui = MetalGUI(design)

#from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket


#q1 = TransmonPocket(design, 'Q1', options=dict(connection_pads=dict(a=dict()))) # Create a new Transmon Pocket object with name 'Q1' 
#gui.rebuild()  # rebuild the design and plot
# Out:
#     <h1 style="
#         background: #12c2e9;  /* fallback for old browsers */
#         background: -webkit-linear-gradient(to right, #d4418e 0%, #0652c5 74%);  /* Chrome 10-25, Safari 5.1-6 */
#         background: linear-gradient(315deg, #d4418e 0%, #0652c5 74%); /* W3C, IE 10+/ Edge, Firefox 16+, Chrome 26+, Opera 12+, Safari 7+ */
#         margin-top: 50px;
#         border-style: outset;
#         padding-top:100px;
#         padding-bottom:50px;
#         padding-left:25px;
#         color: white;
#     "> Welcome to Qiskit Metal! <h1>
# hi
# qmodelindex: filename:  transmon_pocket.py index:  <PySide2.QtCore.QModelIndex(3,0,0x7f90a1995080,LibraryFileProxyModel(0x7f9094d73300))  at 0x7f910979a190>
# manolo
# full path:  /Users/graceharperibm/metal_work/qiskit-metal/qiskit_metal/qlibrary/qubits/transmon_pocket.py
# resized
# about to get class from abd file
# tyring init wrapepr
# rooting dir
# tyring init wrapepr
# returning imported
# got class
# import_class name: TransmonPocket
# import_class: <class 'qiskit_metal.qlibrary.qubits.transmon_pocket.TransmonPocket'>
# self.logger IS:  <Logger metal (DEBUG)>
# tyring init wrapepr
# cur_name name
# entry_type: <class 'str'>
# param.default: None
# initting NormalEntryWidget
# cur_name options
# entry_type: <class 'addict.addict.Dict'>
# param.default: None
# initting dictionary entry widget
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7f90e0abb2d0>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# entry_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7f90e0abb730>
# cur_name options_connection_pads
# entry_type: <class 'addict.addict.Dict'>
# param.default: None
# initting dictionary entry widget
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7f90e0abe280>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# entry_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7f90e0abe190>
# cur_name make
# entry_type: <class 'bool'>
# param.default: True
# initting NormalEntryWidget
# made it
# orig style sheet
#
# old stylesheet
#
# <PySide2.QtWidgets.QStyle object at 0x7f9129567be0>
# should be default style sheet
#
# param_entry made
# param entry showing? : True
# setting up
# running
# Checked is False
# starting
# PySide2.QtCore.QAbstractAnimation.Direction.Forward
# running
# Checked is False
# starting
# PySide2.QtCore.QAbstractAnimation.Direction.Backward
# running
# Checked is False
# starting
# PySide2.QtCore.QAbstractAnimation.Direction.Forward
# running
# Checked is False
# starting
# PySide2.QtCore.QAbstractAnimation.Direction.Backward
# setting up
# running
# Checked is False
# starting
# PySide2.QtCore.QAbstractAnimation.Direction.Forward
# running
# Checked is False
# starting
# PySide2.QtCore.QAbstractAnimation.Direction.Backward
# running
# Checked is False
# starting
# PySide2.QtCore.QAbstractAnimation.Direction.Forward
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7f90e0abe280>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7f90e0abe280>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# cur_collapsable_layout:  <PySide2.QtWidgets.QVBoxLayout object at 0x7f90e0abe280>
# initting DictionaryEntryBox
# value_o run
# value_o added
# box parts added
# remove lambda added
# setup nested button
# running
# Checked is False
# starting
# PySide2.QtCore.QAbstractAnimation.Direction.Backward

# %%
q1.options

# %%
TransmonPocket.options_template
